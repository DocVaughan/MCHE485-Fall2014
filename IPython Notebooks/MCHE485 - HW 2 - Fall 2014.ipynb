# %% [markdown]
# <h1 style="text-align:center">Homework 2 Helper</h1>
# <h3 style="text-align:center"> MCHE 485: Mechanical Vibrations &mdash; Fall 2014</h3>
# <p style="text-align:center">Dr. Joshua Vaughan <br>
# <a href="mailto:joshua.vaughan@louisiana.edu">joshua.vaughan@louisiana.edu</a><br>
# http://www.ucs.louisiana.edu/~jev9637/   </p>

# %%
import numpy as np

# %%
# %matplotlib inline

# Import the plotting functions 
#  Note: Using the 'from module import *' notation is usually a bad idea. 
from matplotlib.pyplot import *

# %% [markdown]
# ## Problem 1.2

# %%
# Let's use the symbolic toolbox Sympy (http://sympy.org) to check our answer here
import sympy 
sympy.init_printing() # initialize "pretty" printing for sympy

w, t = sympy.symbols('\omega t')

# Note: The imaginary number in sympy is I. We need to say use that part of the sympy library, 
#  So, we use sympy.I

f = (1 + 2*sympy.I) * sympy.exp(sympy.I * w * t) + (1 - 2*sympy.I) * sympy.exp(-sympy.I * w * t)

sympy.simplify(f.rewrite(sympy.cos))
# Out:
# -4⋅sin(\omega⋅t) + 2⋅cos(\omega⋅t)

# %% [markdown]
# ## Problem 1.9

# %%
# We're just using the IPython Notebook as a calculator for this problem

t = 1.5 # evaluate the assignments below for t = 1.5s

x = 2 * np.cos(3*t) - np.sin(3*t)
x_dot = -6 * np.sin(3*t) - 3 * np.cos(3*t)
x_ddot = -18 * np.cos(3*t) + 9 * np.sin(3*t)

# Now let's output the values in a "pretty" way
print ''
print 'The position at 1.5s is {:0.2f}m.'.format(x)
print 'The velocity at 1.5s is {:0.2f}m/s.'.format(x_dot)
print 'The acceleration at 1.5 s is {:0.2f}m/s^2.'.format(x_ddot)
print ''
# Out:
# The position at 1.5s is 0.56m.
# The velocity at 1.5s is 6.50m/s.
# The acceleration at 1.5 s is -5.00m/s^2.

# %% [markdown]
# ## Problem 1.14

# %%
# Define the time array
t = np.linspace(0,2*np.pi,1000)         # Define an array of 1000 points between 0 and 2*pi

x = 2 * np.cos(t) + 0.05 * np.sin(10*t)
x_dot = -2 * np.sin(t) + 0.5 * np.cos(10*t)
x_ddot = -2 * np.cos(t) - 5.0 * np.sin(10*t)

# Let's also define the "no noise" version of each of these
x_noNoise = 2 * np.cos(t)
x_dot_noNoise = -2 * np.sin(t)
x_ddot_noNoise = -2 * np.cos(t)

# %%
# Now let's plot the three

# Set the plot size - 3x2 aspect ratio is best
fig = figure(figsize=(6,4))
ax = gca()
subplots_adjust(bottom=0.17,left=0.17,top=0.96,right=0.96)

# Change the axis units to serif
setp(ax.get_ymajorticklabels(),family='serif',fontsize=18)
setp(ax.get_xmajorticklabels(),family='serif',fontsize=18)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':',color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
xlabel('Time (s)',family='serif',fontsize=22,weight='bold',labelpad=5)
ylabel('Position (m)',family='serif',fontsize=22,weight='bold',labelpad=10)

plot(t,x_noNoise,linewidth=2,linestyle = '--',label=r'``Pure" Response')
plot(t,x,linewidth=2, label=r'With Sensor Noise')

# uncomment below and set limits if needed
xlim(0,2*np.pi)
ylim(-3,4)

# Create the legend, then fix the fontsize
leg = legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
setp(ltext,family='serif',fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
# savefig('Prob_1p14_position.pdf')

fig.set_size_inches(9,6) # Resize the figure for better display in the notebook

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = figure(figsize=(6,4))
ax = gca()
subplots_adjust(bottom=0.17,left=0.17,top=0.96,right=0.96)

# Change the axis units to serif
setp(ax.get_ymajorticklabels(),family='serif',fontsize=18)
setp(ax.get_xmajorticklabels(),family='serif',fontsize=18)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':',color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
xlabel('Time (s)',family='serif',fontsize=22,weight='bold',labelpad=5)
ylabel('Velocity (m/s)',family='serif',fontsize=22,weight='bold',labelpad=10)

plot(t,x_dot_noNoise,linewidth=2, linestyle = '--', label=r'``Pure" Response')
plot(t,x_dot,linewidth=2, label=r'With Sensor Noise')

# uncomment below and set limits if needed
xlim(0,2*np.pi)
ylim(-3,5)


# Create the legend, then fix the fontsize
leg = legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
setp(ltext,family='serif',fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
# savefig('Prob_1p14_velocity.pdf')

fig.set_size_inches(9,6) # Resize the figure for better display in the notebook

# %%
# Set the plot size - 3x2 aspect ratio is best
fig = figure(figsize=(6,4))
ax = gca()
subplots_adjust(bottom=0.17,left=0.17,top=0.96,right=0.96)

# Change the axis units to serif
setp(ax.get_ymajorticklabels(),family='serif',fontsize=18)
setp(ax.get_xmajorticklabels(),family='serif',fontsize=18)

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# Turn on the plot grid and set appropriate linestyle and color
ax.grid(True,linestyle=':',color='0.75')
ax.set_axisbelow(True)

# Define the X and Y axis labels
xlabel('Time (s)',family='serif',fontsize=22,weight='bold',labelpad=5)
ylabel(r'Acceleration (m/s$^2$)',family='serif',fontsize=22,weight='bold',labelpad=10)

plot(t,x_ddot_noNoise,linewidth=2, linestyle = '--', label=r'``Pure" Response')
plot(t,x_ddot,linewidth=2, label=r'With Sensor Noise')

# uncomment below and set limits if needed
xlim(0,2*np.pi)
ylim(-8,12)


# Create the legend, then fix the fontsize
leg = legend(loc='upper right', ncol = 1, fancybox=True)
ltext  = leg.get_texts()
setp(ltext,family='serif',fontsize=18)

# Adjust the page layout filling the page using the new tight_layout command
tight_layout(pad=0.5)

# save the figure as a high-res pdf in the current folder
# It's saved at the original 6x4 size
# savefig('Prob_1p14_acceleration.pdf')

fig.set_size_inches(9,6) # Resize the figure for better display in the notebook

# %% [markdown]
# ## Problem 1.37

# %%
# Let's use the symbolic toolbox Sympy (http://sympy.org) to solve this one.
# We've already imported sympy above, if not, we'd need to include the line below
# import sympy 

k, wn1, wn2 = sympy.symbols('k wn1 wn2')

wn1 = sympy.sqrt(k/100)
wn2 = sympy.sqrt(k/156.25)

k = sympy.solve(wn1 - wn2 - 2,k)

print '\nThe resulting spring constant, k, is {:0.2f} N/m.\n'.format(float(k[0]))
# Out:
# The resulting spring constant, k, is 10000.00 N/m.

# %% [markdown]
# ## Problem 1.54

# %%
m = 0.06             # mass (kg)

tau = 0.5            # 0.5s period

wn = (2 * np.pi)/tau # calculate natural frequency from the period (rad/s)

k = m * wn**2        # solve for k

print '\nThe resulting spring constant is {:0.2f} N/m.\n'.format(k)
# Out:
# The resulting spring constant is 9.47 N/m.
